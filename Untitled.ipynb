# %%
import healpy as hp
import numpy as np
from scipy.optimize import minimize
import scipy.constants as const
from pysm import read_map_wrapped
import matplotlib.pyplot as plt
# %matplotlib inline

def safe_log10(x,minval=0.0000000001):
    return np.log10(x.clip(min=minval))

def b_l(ell,sigma):
    return np.exp(-0.5*ell*(ell+1)*sigma**2)

def sigma(fwhm):
    return fwhm*(2.*np.pi/(60.*360.))/(np.sqrt(8.*np.log(2.)))

def fit_cl_conv(map,l_fit,theta):
    cl = hp.anafast(map)
    ell = np.arange(cl.size)
    coeffs = np.polyfit(safe_log10(ell[l_fit[0]:l_fit[1]]),safe_log10(cl[l_fit[0]:l_fit[1]]),1)
    cl_pl = np.power(10,coeffs[1])*np.power(ell,coeffs[0])
    print('Coefficients of power law fit:', coeffs)
    return cl_pl*(1-b_l(ell,sigma(theta*60.))**2)

def local_mean(m,pix,radius): #radius is in radians
    nside= hp.get_nside(m)
    pos = hp.pix2vec(nside,pix)
    inds = hp.query_disc(nside,pos,radius)
    disc_mean = np.mean(m[inds])
    return disc_mean

def mod_gaussian_model(gamma,cl_pl,map_in,nside_o):
    g = hp.synfast(cl_pl[1:],nside=nside_o,verbose=False,new=True)
    ss = (g-np.mean(g))/np.sqrt(np.var(g))*(np.abs(map_in)**gamma)
    return ss

def lognormal_model(gamma,map_in,m_0,R_mean,d_g,d_g_var):
    norm = np.min(map_in)/m_0
    x = R_mean**gamma*d_g-0.5*d_g_var
    return norm*(np.exp(x)-1.)

def chi_sq(gamma,map_in,cl_pl,pl_fit,nside_o,model,m_0=None,R_mean=None,d_g=None,d_g_var=None):
    if model == 'mod_gaussian': 
        model = mod_gaussian_model(gamma,cl_pl,map_in,nside_o)
    if model == 'lognormal':
        model = lognormal_model(gamma,map_in,m_0,R_mean,d_g,d_g_var)
    print gamma
    cl_model = hp.anafast(model)
    ell = np.arange(cl_model.size)
    chi_sq_arg = (cl_model[1:]/cl_pl[1:]-1)**2*(2*ell[1:]+1)/2
    return np.sum(chi_sq_arg[pl_fit[0]:pl_fit[1]])

def mod_gaussian_ss_map(map_in,nside_o,l_fit,pl_fit,theta):
    print('Fitting power law.')
    cl_pl = fit_cl_conv(map_in,l_fit,theta)
    print('Minimizing chi squared at large l.')
    res = minimize(chi_sq,1.3,args=(map_in,cl_pl,pl_fit,nside_o,'mod_gaussian'),method='Powell')
    return mod_gaussian_model(res.x,cl_pl,map_in,nside_o)

def lognormal_ss_map(map_in,nside_o,l_fit,pl_fit,theta):
    m_0 = np.mean(map_in);npix=map_in.size
    d_ls = (map_in-m_0)/m_0
    print('Fitting power law.')
    cl_pl = fit_cl_conv(d_ls,l_fit,theta)
    print('Computing local scaling.')
    R_mean = np.zeros(npix)
    for i in np.arange(npix):
        R_mean[i] = local_mean(map_in,i,(np.pi/180.)*4.)/m_0
    print('Minimizing chi squared.')
    d_g = hp.synfast(cl_pl[1:],nside=nside_o,new=True)
    d_g_var = np.var(d_g)
    res = minimize(chi_sq,1.,args=(map_in,cl_pl,pl_fit,nside_o,'lognormal',m_0,R_mean,d_g,d_g_var),method='Powell')
    d_ss = lognormal_model(res.x,map_in,m_0,R_mean,d_g,d_g_var)
    return m_0*d_ss

def generate_ss_map(map_in,nside_o,l_fit,pl_fit,theta,method):
    if method=='mod_gaussian': return mod_gaussian_ss_map(map_in,nside_o,l_fit,pl_fit,theta)
    if method=='lognormal': return lognormal_ss_map(map_in,nside_o,l_fit,pl_fit,theta)



""" 
OPTIONS:

Details of the map to be extended to small scales.  The map will be
 read in and degraded to the specified nside_in before being used.  Therefore 
if the template is nside 1024 this must be specified as:
 
>nside_in = 1024

The output is generated at nside_out.

The other specified information is:

l_fit:  the multipole range over which the power law is fitted.
theta_res:  the angular scale (in deg) of the limiting resolution of the input.
pl_fit: range of multipoles over which the chi_sq fits.

"""

method = 'lognormal'  #options are 'lognormal' or 'mod_gaussian'

nside_in = 256
nside_out = 256

l_fit = [20.,50.]
pl_fit = [400.,600.]

theta_res = 1.   

file_in = './Ancillaries/Synchrotron/mamd2008/haslam408_dsds_Remazeilles2014_8p33_mono_sub.fits'
file_out = './Ancillaries/Synchrotron/mamd2008/haslam408_dsds_Remazeilles2014_8p33_mono_sub_ss.fits'

# %%
"""
MAIN CODE
"""

map_in = read_map_wrapped(file_in, nside_in, 0)
map_ss = generate_ss_map(map_in,nside_out,l_fit,pl_fit,theta_res,method)

print('Writing new small scale map to '+file_out)

hp.write_map(file_out,map_in+map_ss)
# Out:
# Fitting power law.
# ('Coefficients of power law fit:', array([-2.50087684,  0.97857593]))
# Computing local scaling.
# Minimizing chi squared.
# Sigma is 0.000000 arcmin (0.000000 rad)
# -> fwhm is 0.000000 arcmin
# [ 1.]
# /Users/benthorne/Library/Python/2.7/lib/python/site-packages/ipykernel/__main__.py:20: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /Users/benthorne/Library/Python/2.7/lib/python/site-packages/ipykernel/__main__.py:21: RuntimeWarning: divide by zero encountered in power
# /Users/benthorne/Library/Python/2.7/lib/python/site-packages/ipykernel/__main__.py:23: RuntimeWarning: invalid value encountered in multiply
# /Users/benthorne/Library/Python/2.7/lib/python/site-packages/ipykernel/__main__.py:51: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# [ 1.]
# [ 2.]
# [-0.618034]
# [ 0.190983]
# [-3.23606803]
# [-0.618034]
# [-1.61803398]
# [ -2.51559999e-08]
# [-0.30904783]
# [-0.99999999]
# [-1.23606797]
# [-1.381966]
# [-1.14589803]
# [-1.29179605]
# [-1.32623791]
# [-1.26887809]
# [-3.58359211]
# [-1.29179605]
# [-0.29179605]
# [-2.90983005]
# [-1.29179605]
# [-1.90983003]
# [-0.90983005]
# [-1.10081319]
# [-1.52786402]
# [-1.38196599]
# [-1.21884709]
# [-1.3262379]
# [-1.27830543]
# [-1.29020501]
# [-1.29299441]
# [-1.29269984]
# [-1.2926908]
# [-1.29268185]
# [-1.29358555]
# [-1.2926908]
# [-0.2926908]
# [-2.9107248]
# [-1.2926908]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-f1faf17161e4> in <module>()
#       5
#       6 map_in = read_map_wrapped(file_in, nside_in, 0)
# ----> 7 map_ss = generate_ss_map(map_in,nside_out,l_fit,pl_fit,theta_res,method)
#       8
#       9 print('Writing new small scale map to '+file_out)
#
# <ipython-input-1-05d26f19cbe9> in generate_ss_map(map_in, nside_o, l_fit, pl_fit, theta, method)
#      76 def generate_ss_map(map_in,nside_o,l_fit,pl_fit,theta,method):
#      77     if method=='mod_gaussian': return mod_gaussian_ss_map(map_in,nside_o,l_fit,pl_fit,theta)
# ---> 78     if method=='lognormal': return lognormal_ss_map(map_in,nside_o,l_fit,pl_fit,theta)
#      79
#      80
#
# <ipython-input-1-05d26f19cbe9> in lognormal_ss_map(map_in, nside_o, l_fit, pl_fit, theta)
#      70     d_g = hp.synfast(cl_pl[1:],nside=nside_o,new=True)
#      71     d_g_var = np.var(d_g)
# ---> 72     res = minimize(chi_sq,1.,args=(map_in,cl_pl,pl_fit,nside_o,'lognormal',m_0,R_mean,d_g,d_g_var),method='Powell')
#      73     d_ss = lognormal_model(res.x,map_in,m_0,R_mean,d_g,d_g_var)
#      74     return m_0*d_ss
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/optimize/_minimize.pyc in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     364         return _minimize_neldermead(fun, x0, args, callback, **options)
#     365     elif meth == 'powell':
# --> 366         return _minimize_powell(fun, x0, args, callback, **options)
#     367     elif meth == 'cg':
#     368         return _minimize_cg(fun, x0, args, jac, callback, **options)
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/optimize/optimize.pyc in _minimize_powell(func, x0, args, callback, xtol, ftol, maxiter, maxfev, disp, direc, return_all, **unknown_options)
#    2295             fx2 = fval
#    2296             fval, x, direc1 = _linesearch_powell(func, x, direc1,
# -> 2297                                                  tol=xtol * 100)
#    2298             if (fx2 - fval) > delta:
#    2299                 delta = fx2 - fval
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/optimize/optimize.pyc in _linesearch_powell(func, p, xi, tol)
#    2113     def myfunc(alpha):
#    2114         return func(p + alpha*xi)
# -> 2115     alpha_min, fret, iter, num = brent(myfunc, full_output=1, tol=tol)
#    2116     xi = alpha_min*xi
#    2117     return squeeze(fret), p + xi, xi
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/optimize/optimize.pyc in brent(func, args, brack, tol, full_output, maxiter)
#    1878     options = {'xtol': tol,
#    1879                'maxiter': maxiter}
# -> 1880     res = _minimize_scalar_brent(func, brack, args, **options)
#    1881     if full_output:
#    1882         return res['x'], res['fun'], res['nit'], res['nfev']
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/optimize/optimize.pyc in _minimize_scalar_brent(func, brack, args, xtol, maxiter, **unknown_options)
#    1894                   full_output=True, maxiter=maxiter)
#    1895     brent.set_bracket(brack)
# -> 1896     brent.optimize()
#    1897     x, fval, nit, nfev = brent.get_result(full_output=True)
#    1898     return Result(fun=fval, x=x, nit=nit, nfev=nfev)
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/optimize/optimize.pyc in optimize(self)
#    1726         #################################
#    1727         x = w = v = xb
# -> 1728         fw = fv = fx = func(*((x,) + self.args))
#    1729         if (xa < xc):
#    1730             a = xa
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/optimize/optimize.pyc in myfunc(alpha)
#    2112     """
#    2113     def myfunc(alpha):
# -> 2114         return func(p + alpha*xi)
#    2115     alpha_min, fret, iter, num = brent(myfunc, full_output=1, tol=tol)
#    2116     xi = alpha_min*xi
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/optimize/optimize.pyc in function_wrapper(*wrapper_args)
#     279     def function_wrapper(*wrapper_args):
#     280         ncalls[0] += 1
# --> 281         return function(*(wrapper_args + args))
#     282
#     283     return ncalls, function_wrapper
#
# <ipython-input-1-05d26f19cbe9> in chi_sq(gamma, map_in, cl_pl, pl_fit, nside_o, model, m_0, R_mean, d_g, d_g_var)
#      46         model = lognormal_model(gamma,map_in,m_0,R_mean,d_g,d_g_var)
#      47     print gamma
# ---> 48     cl_model = hp.anafast(model)
#      49     ell = np.arange(cl_model.size)
#      50     chi_sq_arg = (cl_model[1:]/cl_pl[1:]-1)**2*(2*ell[1:]+1)/2
#
# /Users/benthorne/Library/Python/2.7/lib/python/site-packages/healpy/sphtfunc.pyc in anafast(map1, map2, nspec, lmax, mmax, iter, alm, pol, use_weights, datapath)
#      93     alms1 = map2alm(map1, lmax = lmax, mmax = mmax, pol = pol, iter = iter,
#      94                     use_weights = use_weights,
# ---> 95                     datapath = datapath)
#      96     if map2 is not None:
#      97         map2 = ma_to_array(map2)
#
# /Users/benthorne/Library/Python/2.7/lib/python/site-packages/healpy/sphtfunc.pyc in map2alm(maps, lmax, mmax, iter, pol, use_weights, datapath)
#     155         alms = _sphtools.map2alm(maps, niter = iter,
#     156                                  datapath = datapath, use_weights = use_weights,
# --> 157                                  lmax = lmax, mmax = mmax)
#     158     else:
#     159         # info >= 2 and pol is False : spin 0 spht for each map
#
# KeyboardInterrupt:

# %%
#cl_out = hp.anafast(map_ss+map_in)

# %%
#plt.xscale('log');plt.yscale('log')
#plt.plot(hp.anafast(map_in));plt.plot(cl_out)
#plt.show()

# %%
m_0 = np.mean(map_in);npix=map_in.size
d_ls = (map_in-m_0)/m_0
print('Fitting power law.')
cl_pl = fit_cl_conv(d_ls,l_fit,theta_res)
print('Computing local scaling.')
R_mean = np.zeros(npix)
for i in np.arange(npix):
    R_mean[i] = local_mean(map_in,i,(np.pi/180.)*4.)/m_0
print('Minimizing chi squared.')

# %%
nside_o = np.copy(nside_out)

# %%
d_g = hp.synfast(cl_pl[1:],nside=nside_o,new=True)
d_g_var = np.var(d_g)
# Out:
# Sigma is 0.000000 arcmin (0.000000 rad)
# -> fwhm is 0.000000 arcmin

# %%
gamma=0.56
norm = np.min(map_in)/m_0
x = (R_mean**gamma/np.mean(R_mean**gamma))*d_g-0.5*d_g_var
ln = norm*(np.exp(x)-1.)

# %%
hp.mollview(m_0*np.exp(R_mean**0.4*d_g)+map_in,norm='log')

# %%
res = minimize(chi_sq,.6,args=(map_in,cl_pl,pl_fit,nside_o,'lognormal',m_0,R_mean,d_g,d_g_var),method='Powell')
# Out:
# [ 0.6]
# [ 0.6]
# [ 1.6]
# [-1.018034]
# [ 0.6]
# [-0.01803397]
# [ 0.981966]
# [ 0.29098301]
# [ 0.74589803]
# [ 0.48196602]
# [ 0.65572809]
# [ 0.55491503]
# [ 0.6343639]
# [ 0.58277908]
# [ 0.58032023]
# [ 0.58562343]
# [ 0.59111479]
# [ 0.58749428]
# [ 0.58762515]
# [ 0.58777437]
# [ 0.58789663]
# [ 0.57554874]
# [ 0.58777437]
# [ 0.57554874]
# [ 0.60755585]
# [ 0.58777437]
# [ 0.59533023]
# [ 0.5831046]
# [ 0.58716078]
# [ 0.58780988]
# [ 0.58775725]
# [ 0.58775799]
# [ 0.58775782]
# [ 0.58775815]
# [ 0.58775799]
# [ 0.5877416]
# [ 0.5877845]
# [ 0.58775799]
# [ 0.58776811]
# [ 0.58775173]
# [ 0.58775797]
# [ 0.58775797]
# /Users/benthorne/Library/Python/2.7/lib/python/site-packages/ipykernel/__main__.py:52: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-60-0e85cc64df21> in <module>()
# ----> 1 res = minimize(chi_sq,.6,args=(map_in,cl_pl,pl_fit,nside_o,'lognormal',m_0,R_mean,d_g,d_g_var),method='Powell')
#       2
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/optimize/_minimize.pyc in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     364         return _minimize_neldermead(fun, x0, args, callback, **options)
#     365     elif meth == 'powell':
# --> 366         return _minimize_powell(fun, x0, args, callback, **options)
#     367     elif meth == 'cg':
#     368         return _minimize_cg(fun, x0, args, jac, callback, **options)
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/optimize/optimize.pyc in _minimize_powell(func, x0, args, callback, xtol, ftol, maxiter, maxfev, disp, direc, return_all, **unknown_options)
#    2295             fx2 = fval
#    2296             fval, x, direc1 = _linesearch_powell(func, x, direc1,
# -> 2297                                                  tol=xtol * 100)
#    2298             if (fx2 - fval) > delta:
#    2299                 delta = fx2 - fval
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/optimize/optimize.pyc in _linesearch_powell(func, p, xi, tol)
#    2113     def myfunc(alpha):
#    2114         return func(p + alpha*xi)
# -> 2115     alpha_min, fret, iter, num = brent(myfunc, full_output=1, tol=tol)
#    2116     xi = alpha_min*xi
#    2117     return squeeze(fret), p + xi, xi
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/optimize/optimize.pyc in brent(func, args, brack, tol, full_output, maxiter)
#    1878     options = {'xtol': tol,
#    1879                'maxiter': maxiter}
# -> 1880     res = _minimize_scalar_brent(func, brack, args, **options)
#    1881     if full_output:
#    1882         return res['x'], res['fun'], res['nit'], res['nfev']
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/optimize/optimize.pyc in _minimize_scalar_brent(func, brack, args, xtol, maxiter, **unknown_options)
#    1894                   full_output=True, maxiter=maxiter)
#    1895     brent.set_bracket(brack)
# -> 1896     brent.optimize()
#    1897     x, fval, nit, nfev = brent.get_result(full_output=True)
#    1898     return Result(fun=fval, x=x, nit=nit, nfev=nfev)
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/optimize/optimize.pyc in optimize(self)
#    1783             else:
#    1784                 u = x + rat
# -> 1785             fu = func(*((u,) + self.args))      # calculate new output value
#    1786             funcalls += 1
#    1787
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/optimize/optimize.pyc in myfunc(alpha)
#    2112     """
#    2113     def myfunc(alpha):
# -> 2114         return func(p + alpha*xi)
#    2115     alpha_min, fret, iter, num = brent(myfunc, full_output=1, tol=tol)
#    2116     xi = alpha_min*xi
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/optimize/optimize.pyc in function_wrapper(*wrapper_args)
#     279     def function_wrapper(*wrapper_args):
#     280         ncalls[0] += 1
# --> 281         return function(*(wrapper_args + args))
#     282
#     283     return ncalls, function_wrapper
#
# <ipython-input-59-a8da8c90cc20> in chi_sq(gamma, map_in, cl_pl, pl_fit, nside_o, model, m_0, R_mean, d_g, d_g_var)
#      47         model = lognormal_model(gamma,map_in,m_0,R_mean,d_g,d_g_var)
#      48     print gamma
# ---> 49     cl_model = hp.anafast(model)
#      50     ell = np.arange(cl_model.size)
#      51     chi_sq_arg = (cl_model[1:]/cl_pl[1:]-1)**2*(2*ell[1:]+1)/2
#
# /Users/benthorne/Library/Python/2.7/lib/python/site-packages/healpy/sphtfunc.pyc in anafast(map1, map2, nspec, lmax, mmax, iter, alm, pol, use_weights, datapath)
#      93     alms1 = map2alm(map1, lmax = lmax, mmax = mmax, pol = pol, iter = iter,
#      94                     use_weights = use_weights,
# ---> 95                     datapath = datapath)
#      96     if map2 is not None:
#      97         map2 = ma_to_array(map2)
#
# /Users/benthorne/Library/Python/2.7/lib/python/site-packages/healpy/sphtfunc.pyc in map2alm(maps, lmax, mmax, iter, pol, use_weights, datapath)
#     155         alms = _sphtools.map2alm(maps, niter = iter,
#     156                                  datapath = datapath, use_weights = use_weights,
# --> 157                                  lmax = lmax, mmax = mmax)
#     158     else:
#     159         # info >= 2 and pol is False : spin 0 spht for each map
#
# KeyboardInterrupt:

# %%
d_ss = lognormal_model(res.x,map_in,m_0,R_mean,d_g,d_g_var)

# %%
plt.xscale('log');plt.yscale('log')
plt.plot(hp.anafast(map_in))
plt.plot(hp.anafast(m_0*d_ss+map_in))
